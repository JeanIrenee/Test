# %% [markdown]
# # 1. Euler Method

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def EulerMethod(a,b,c,N,f):
#     h = (b-a)/N
    x = np.linspace(a,b,N+1)
    h = x[1] - x[0]
    y = np.zeros(N+1) 
#     y = np.zeros(len(x)) 
    y[0] = c
    for i in range(0,N):
        y[i+1] = y[i] + h*f(y[i],x[i])
    return y

# %%
def EulerMethod1(f,c,t):

    h = t[1] - t[0]
    y = np.zeros(len(t)) 
#     y = np.zeros(len(x)) 
    y[0] = c
    for i in range(0,len(t)-1):
        y[i+1] = y[i] + h*f(y[i],t[i])
    return y

# %%
a = 0
b = 1
c = 1/9
N = 100

def f(y,x):
    return np.exp(x)/(3+6*np.exp(x))

# g = lambda y,x: np.exp(x)/(3+6*np.exp(x))


EulerMethod(a,b,c,N,f)
# Out:
# array([0.11111111, 0.11222222, 0.11333703, 0.11445552, 0.11557769,
#        0.11670352, 0.11783299, 0.1189661 , 0.12010282, 0.12124316,
#        0.12238709, 0.1235346 , 0.12468568, 0.12584031, 0.12699849,
#        0.12816019, 0.1293254 , 0.13049411, 0.13166631, 0.13284197,
#        0.1340211 , 0.13520366, 0.13638965, 0.13757906, 0.13877187,
#        0.13996805, 0.14116761, 0.14237053, 0.14357678, 0.14478636,
#        0.14599924, 0.14721542, 0.14843489, 0.14965761, 0.15088359,
#        0.1521128 , 0.15334522, 0.15458086, 0.15581967, 0.15706167,
#        0.15830681, 0.1595551 , 0.16080652, 0.16206105, 0.16331867,
#        0.16457936, 0.16584313, 0.16710994, 0.16837978, 0.16965263,
#        0.17092849, 0.17220733, 0.17348913, 0.17477389, 0.17606159,
#        0.1773522 , 0.17864572, 0.17994213, 0.18124141, 0.18254354,
#        0.18384852, 0.18515631, 0.18646692, 0.18778032, 0.1890965 ,
#        0.19041543, 0.19173711, 0.19306151, 0.19438863, 0.19571845,
#        0.19705094, 0.1983861 , 0.1997239 , 0.20106434, 0.20240739,
#        0.20375304, 0.20510128, 0.20645208, 0.20780544, 0.20916133,
#        0.21051974, 0.21188066, 0.21324406, 0.21460994, 0.21597828,
#        0.21734906, 0.21872226, 0.22009787, 0.22147588, 0.22285627,
#        0.22423902, 0.22562411, 0.22701154, 0.22840129, 0.22979334,
#        0.23118767, 0.23258428, 0.23398314, 0.23538424, 0.23678756,
#        0.23819309])

# %%
t = np.linspace(a,b,N+1)
EulerMethod1(f,c,t)
# Out:
# array([0.11111111, 0.11222222, 0.11333703, 0.11445552, 0.11557769,
#        0.11670352, 0.11783299, 0.1189661 , 0.12010282, 0.12124316,
#        0.12238709, 0.1235346 , 0.12468568, 0.12584031, 0.12699849,
#        0.12816019, 0.1293254 , 0.13049411, 0.13166631, 0.13284197,
#        0.1340211 , 0.13520366, 0.13638965, 0.13757906, 0.13877187,
#        0.13996805, 0.14116761, 0.14237053, 0.14357678, 0.14478636,
#        0.14599924, 0.14721542, 0.14843489, 0.14965761, 0.15088359,
#        0.1521128 , 0.15334522, 0.15458086, 0.15581967, 0.15706167,
#        0.15830681, 0.1595551 , 0.16080652, 0.16206105, 0.16331867,
#        0.16457936, 0.16584313, 0.16710994, 0.16837978, 0.16965263,
#        0.17092849, 0.17220733, 0.17348913, 0.17477389, 0.17606159,
#        0.1773522 , 0.17864572, 0.17994213, 0.18124141, 0.18254354,
#        0.18384852, 0.18515631, 0.18646692, 0.18778032, 0.1890965 ,
#        0.19041543, 0.19173711, 0.19306151, 0.19438863, 0.19571845,
#        0.19705094, 0.1983861 , 0.1997239 , 0.20106434, 0.20240739,
#        0.20375304, 0.20510128, 0.20645208, 0.20780544, 0.20916133,
#        0.21051974, 0.21188066, 0.21324406, 0.21460994, 0.21597828,
#        0.21734906, 0.21872226, 0.22009787, 0.22147588, 0.22285627,
#        0.22423902, 0.22562411, 0.22701154, 0.22840129, 0.22979334,
#        0.23118767, 0.23258428, 0.23398314, 0.23538424, 0.23678756,
#        0.23819309])

# %%
def RangeKutta2(a,b,c,N,f):
#     h = (b-a)/N
    x = np.linspace(a,b,N+1)
    h = x[1] - x[0]
    y = np.zeros(N+1) 
#     y = np.zeros(len(x)) 
    y[0] = c
    for i in range(0,N):
        k1 = h*f(y[i],x[i])
        k2 = h*f(y[i]+k1,x[i]+h)
        y[i+1] = y[i] + (1/2)*(k1+k2)
    return y

# %%
RangeKutta2(a,b,c,N,f)
# Out:
# array([0.11111111, 0.11222407, 0.11334072, 0.11446105, 0.11558505,
#        0.1167127 , 0.11784399, 0.1189789 , 0.12011744, 0.12125957,
#        0.12240529, 0.12355458, 0.12470744, 0.12586384, 0.12702378,
#        0.12818724, 0.1293542 , 0.13052465, 0.13169858, 0.13287598,
#        0.13405682, 0.1352411 , 0.1364288 , 0.13761991, 0.1388144 ,
#        0.14001228, 0.14121351, 0.1424181 , 0.14362601, 0.14483724,
#        0.14605178, 0.1472696 , 0.14849069, 0.14971504, 0.15094264,
#        0.15217345, 0.15340748, 0.15464471, 0.15588512, 0.15712869,
#        0.1583754 , 0.15962526, 0.16087823, 0.1621343 , 0.16339346,
#        0.16465569, 0.16592098, 0.1671893 , 0.16846065, 0.169735  ,
#        0.17101235, 0.17229267, 0.17357596, 0.17486218, 0.17615134,
#        0.1774434 , 0.17873837, 0.18003621, 0.18133692, 0.18264047,
#        0.18394686, 0.18525606, 0.18656807, 0.18788285, 0.18920041,
#        0.19052071, 0.19184376, 0.19316952, 0.19449798, 0.19582914,
#        0.19716296, 0.19849944, 0.19983856, 0.20118031, 0.20252466,
#        0.2038716 , 0.20522112, 0.2065732 , 0.20792783, 0.20928498,
#        0.21064464, 0.21200681, 0.21337145, 0.21473856, 0.21610811,
#        0.2174801 , 0.21885451, 0.22023132, 0.22161052, 0.22299209,
#        0.22437601, 0.22576227, 0.22715086, 0.22854176, 0.22993495,
#        0.23133042, 0.23272815, 0.23412813, 0.23553034, 0.23693477,
#        0.2383414 ])

# %%
def RangeKutta4(a,b,c,N,f):
#     h = (b-a)/N
    x = np.linspace(a,b,N+1)
    h = x[1] - x[0]
    y = np.zeros(N+1) 
#     y = np.zeros(len(x)) 
    y[0] = c
    for i in range(0,N):
        k1 = h*f(y[i],x[i])
        k2 = h*f(y[i]+(k1/2),x[i]+(h/2))
        k3 = h*f(y[i]+(k2/2),x[i]+(h/2))
        k4 = h*f(y[i]+k3,x[i]+h)
        y[i+1] = y[i] + (1/6)*(k1+2*k2+2*k3+k4)
    return y

# %%
RangeKutta4(a,b,c,N,f)
# Out:
# array([0.11111111, 0.11222407, 0.11334072, 0.11446106, 0.11558505,
#        0.1167127 , 0.11784399, 0.11897891, 0.12011744, 0.12125958,
#        0.1224053 , 0.1235546 , 0.12470745, 0.12586386, 0.1270238 ,
#        0.12818725, 0.12935422, 0.13052467, 0.1316986 , 0.132876  ,
#        0.13405685, 0.13524113, 0.13642883, 0.13761993, 0.13881443,
#        0.14001231, 0.14121354, 0.14241813, 0.14362604, 0.14483728,
#        0.14605181, 0.14726964, 0.14849073, 0.14971508, 0.15094268,
#        0.1521735 , 0.15340753, 0.15464475, 0.15588516, 0.15712873,
#        0.15837545, 0.15962531, 0.16087828, 0.16213435, 0.16339351,
#        0.16465574, 0.16592103, 0.16718936, 0.16846071, 0.16973506,
#        0.17101241, 0.17229274, 0.17357602, 0.17486225, 0.1761514 ,
#        0.17744347, 0.17873844, 0.18003628, 0.18133699, 0.18264055,
#        0.18394693, 0.18525614, 0.18656814, 0.18788293, 0.18920049,
#        0.19052079, 0.19184384, 0.1931696 , 0.19449807, 0.19582922,
#        0.19716305, 0.19849953, 0.19983865, 0.2011804 , 0.20252475,
#        0.2038717 , 0.20522122, 0.2065733 , 0.20792793, 0.20928508,
#        0.21064475, 0.21200691, 0.21337155, 0.21473866, 0.21610822,
#        0.21748021, 0.21885462, 0.22023143, 0.22161063, 0.2229922 ,
#        0.22437612, 0.22576239, 0.22715098, 0.22854187, 0.22993507,
#        0.23133054, 0.23272827, 0.23412825, 0.23553047, 0.2369349 ,
#        0.23834153])

# %%
def EulerMethodSyst(a,b,c,N,f):
#     h = (b-a)/N
    t = np.linspace(a,b,N+1)
    h = t[1] - t[0]
    z = np.zeros((N+1,len(c))) 
#     y = np.zeros(len(x)) 
    y[0,] = c
    for i in range(0,N):
        z[i+1,] = z[i,] + h*f(z[i,],t[i])
    return z
